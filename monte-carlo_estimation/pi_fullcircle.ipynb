# %%
import numpy as np
from matplotlib import pyplot as plt
from tqdm import trange
import numba as nb

# %%
def plot_concept(samples=1_000_000):
    plt.figure(figsize=(5,5))
    radius = 2
    xy_off  = np.random.random([samples,2])
    xy = radius*(xy_off-0.5)
    xy2 = xy**2
    r2 = np.sum(xy2, axis=1)
    # pi = radius**2*np.sum(r2<=1)/samples
    col  = np.full(samples, 'blue')
    col[r2>1] = 'red'
    plt.scatter(xy[:,0], xy[:,1],color=col, s=0.01)
    plt.show()

plot_concept()

# %%
# @nb.jit(nopython=True)
def est_pi(samples=1_000_000):
    radius = 2
    xy_off  = np.random.random([samples,2])
    xy = radius*(xy_off-0.5)
    xy2 = xy**2
    r2 = np.sum(xy2, axis=1)
    pi = radius**2*np.sum(r2<=1)/samples
    return pi

# %%
nmbr = 1_000
pis = np.full(nmbr, 0.0)

t = trange(nmbr)
for i in t:
    pis[i] = est_pi()
    pi_cur = np.sum(pis[0:i+1])/(i+1)
    t.set_description("pi = {:0.7f}".format(pi_cur)
                     + ", " +
                     "off = {:0.7f}".format(np.abs(pi_cur-np.pi))
                     )
    # t.refresh()
# Out:
# pi = 3.141561:   9%|▉         | 93/1000 [00:03<00:29, 30.45it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/bdan/lib/pi/monte-carlo_estimation/pi_fullcircle.ipynb Cell 4' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/home/bdan/lib/pi/monte-carlo_estimation/pi_fullcircle.ipynb#ch0000003?line=3'>4</a> t = trange(nmbr)
#       <a href='vscode-notebook-cell:/home/bdan/lib/pi/monte-carlo_estimation/pi_fullcircle.ipynb#ch0000003?line=4'>5</a> for i in t:
# ----> <a href='vscode-notebook-cell:/home/bdan/lib/pi/monte-carlo_estimation/pi_fullcircle.ipynb#ch0000003?line=5'>6</a>     pis[i] = est_pi()
#       <a href='vscode-notebook-cell:/home/bdan/lib/pi/monte-carlo_estimation/pi_fullcircle.ipynb#ch0000003?line=6'>7</a>     t.set_description("pi = {:0.6f}".format(np.sum(pis[0:i+1])/(i+1)))
#
# /home/bdan/lib/pi/monte-carlo_estimation/pi_fullcircle.ipynb Cell 3' in est_pi(samples)
#       <a href='vscode-notebook-cell:/home/bdan/lib/pi/monte-carlo_estimation/pi_fullcircle.ipynb#ch0000002?line=4'>5</a> xy = radius*(xy_off-0.5)
#       <a href='vscode-notebook-cell:/home/bdan/lib/pi/monte-carlo_estimation/pi_fullcircle.ipynb#ch0000002?line=5'>6</a> xy2 = xy**2
# ----> <a href='vscode-notebook-cell:/home/bdan/lib/pi/monte-carlo_estimation/pi_fullcircle.ipynb#ch0000002?line=6'>7</a> r2 = np.sum(xy2, axis=1)
#       <a href='vscode-notebook-cell:/home/bdan/lib/pi/monte-carlo_estimation/pi_fullcircle.ipynb#ch0000002?line=7'>8</a> pi = radius**2*np.sum(r2<=1)/samples
#       <a href='vscode-notebook-cell:/home/bdan/lib/pi/monte-carlo_estimation/pi_fullcircle.ipynb#ch0000002?line=8'>9</a> return pi
#
# File <__array_function__ internals>:5, in sum(*args, **kwargs)
#
# File ~/envs/all/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2259, in sum(a, axis, dtype, out, keepdims, initial, where)
#    <a href='file:///home/bdan/envs/all/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=2255'>2256</a>         return out
#    <a href='file:///home/bdan/envs/all/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=2256'>2257</a>     return res
# -> <a href='file:///home/bdan/envs/all/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=2258'>2259</a> return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    <a href='file:///home/bdan/envs/all/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=2259'>2260</a>                       initial=initial, where=where)
#
# File ~/envs/all/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      <a href='file:///home/bdan/envs/all/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=82'>83</a>         else:
#      <a href='file:///home/bdan/envs/all/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=83'>84</a>             return reduction(axis=axis, out=out, **passkwargs)
# ---> <a href='file:///home/bdan/envs/all/lib/python3.9/site-packages/numpy/core/fromnumeric.py?line=85'>86</a> return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:
